# %%
import json
import requests as re

def get_data(word):
    url = f'https://tatoeba.org/eng/api_v0/search?from=eng&trans_filter=limit&query={word}&sort=created&trans_to=spa,fra,deu'

    response = re.get(url)
    data = response.json()

    if response.status_code != 200:
        print("Error - Could not get the appropriate data!")

    else:
        print(f'Status code: {response}')


word = input("Enter the desired word :- ")
get_data(word)
print(response.json())
# Out:
# Status code: <Response [200]>
# ...
